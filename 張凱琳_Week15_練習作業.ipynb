# %% [markdown]
# <a href="https://colab.research.google.com/github/A109010090/Computational-Thinking-and-Program-Design/blob/main/%E5%BC%B5%E5%87%B1%E7%90%B3_Week15_%E7%B7%B4%E7%BF%92%E4%BD%9C%E6%A5%AD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**-- 期末報告 --**
#
# 組長(學號姓名):A109010090 張凱琳
#
# 組員(學號姓名):A109010045 張芳瑜、A109010126 康婕柔

# %% [markdown]
# ##**題目: 聊天機器人帶你做心理評估**
# ##**腳本**:
#
# ### ＃1.聊天機器人自我介紹 & 打招呼，取得對方名字
# 機器人:嗨！你好，請問大名？
#
# 測試者: (回答名字)
#
# 機器人:(測試者的名字)，很高興認識你!
#
# 機器人:我叫Robot，是一個聊天機器人。
#
# -
# ### ＃2. 簡單的開頭對話，說明主題及答題方式
# 機器人:你最近會覺得因為心累，所以做事常提不起勁嗎?
#
# 機器人:是什麼原因呢?
#
# 測試者: (回答問題)
#
# 機器人:沒關係。現在你可以一起來做做看下面的心理評估喔!
#
# -
# ### ＃3. 測驗開始作答
# **心理測驗標題:你的厭世指數，用10個問題馬上測!**
#
# **測驗規則:測驗規則:以下問題若答案為No請回答0，Yes請回答1**
#
# ＊題目1:最近嘆氣的次數愈來愈多
#
# 測試者: (回答0或1)
#
# ＊題目2:對人際交往感到厭煩，聽到手機響起就覺得煩躁無力?
#
# 測試者: (回答0或1)
#
# ＊題目3:不太在乎自己的穿著，對時裝也失去興趣?
#
# 測試者: (回答0或1)
#
# ＊題目4:認為運動好麻煩，會盡可能在家宅
#
# 測試者: (回答0或1)
#
# ＊題目5:吃什麼都淡而無味，對美食失去興趣
#
# 測試者: (回答0或1)
#
# ＊題目6:最近的活動範圍只有家裡、公司或學校
#
# 測試者: (回答0或1)
#
# ＊題目7:明明有件事需要處理，卻遲遲未開始
#
# 測試者: (回答0或1)
#
# ＊題目8:失去上進心，覺得「現在這樣也不錯」
#
# 測試者: (回答0或1)
#
# ＊題目9:認為談戀愛是麻煩事
#
# 測試者: (回答0或1)
#
# ＊題目10:放假時大多數時間都在睡覺
#
# 測試者: (回答0或1)
#
# -
# ### ＃4. 分數計算
#
# 機器人:總分是...(計算分數)
#
# -
# ### ＃5. 測驗結果
#
# **0~2 個勾勾：**
#
# 繼續維持下去吧!恭喜你，你的心累指數只有10%！只要有想做的事情，你就會馬上去做，有想去的地方你也會馬上出發，每天都過得不無聊、滿充實的喔！內心變得充實的話，行動力也會隨之提高，相信你之後也會一步步的實現自己想做的事呢！繼續保持現在的良好狀態，試著接受不同的挑戰，吸收各式各樣的新事物吧！不過在努力的同時，也要記得好好休息喔！
#
# **3~5 個勾勾：**
#
# 要注意安撫情緒喔！你的心累指數是 40%，仍然是非常有活力的人。不過要小心一旦發生什麼事情，情緒可能容易變得消沉。你不是消極的人，反而是個努力家，但有時候過於努力，反而會造成疲倦與壓力。在到達極限之前，不如先抽個空讓自己好好休息。不然太過沉重的壓力有可能會壓垮你喔。
#
# **6~8 個勾勾：**
#
# 你已經有點危險了！你的心累指數是 60%，已經有點累了呢！但再這樣下去，壓力是不會消失的！你也是依然有想挑戰的新事物，但只有空想卻無法下定決心，只會讓時間一分一秒逝去。你可能心有餘而力不足，覺得有點不甘心；那就先試著從小小的挑戰開始做起吧！
#
# **9~10 個勾勾：**
#
# 「快樂」是你的頭號課題！你的厭世指數有 80%，非常的高喔！你的內心狀態非常疲倦，每天的生活也讓你感到乏味至極。如果什麼事都覺得無聊又無趣的話，是因為你的內心狀態已經很疲倦，也很久沒有展開笑容了吧？對你來說，現在最重要的就是找回你自己的時間，試著一步步找到喜歡並且感興趣的事，努力讓自己重新充滿活力，再度快樂起來吧！
#
# -
# ### ＃６. 簡單道別
# 機器人:測驗做完啦!你覺得有準嗎?
#
# 測試者: (回答問題)
#
# 機器人:嗯嗯，那改天再聊吧!希望下次見到你的時候，你更健康快樂了喔!
#
# 機器人:再見，(測試者名字)

# %%
# 1.聊天機器人自我介紹 & 打招呼，取得對方名字
name = input("嗨！你/妳好，請問大名？: ")
print(name, "很高興認識你! ")
print("我叫Robot，是一個聊天機器人。")

# 2. 簡單的開頭對話，說明主題及答題方式
Introdution = "你最近會覺得因為心累，所以做事常提不起勁嗎? "
print( Introdution )
reason = input("是什麼原因呢?： ")
print("沒關係。現在你可以一起來做做看下面的心理評估喔! ")
print("你的厭世指數，用10個問題馬上測! 以下問題若答案為No請回答0，Yes請回答1　")

# 3. 測驗開始作答
Q1=int(input("最近嘆氣的次數愈來愈多　"))
Q2=int(input("對人際交往感到厭煩，聽到手機響起就覺得煩躁無力　"))
Q3=int(input("不太在乎自己的穿著，對時裝也失去興趣　"))
Q4=int(input("認為運動好麻煩，會盡可能在家宅　"))
Q5=int(input("吃什麼都淡而無味，對美食失去興趣　"))
Q6=int(input("最近的活動範圍只有家裡、公司或學校　"))
Q7=int(input("明明有件事需要處理，卻遲遲未開始　"))
Q8=int(input("失去上進心，覺得「現在這樣也不錯」　"))
Q9=int(input("認為談戀愛是麻煩事　"))
Q10=int(input("放假時大多數時間都在睡覺　"))

# 4. 分數計算
Total=(Q1+Q2+Q3+Q4+Q5+Q6+Q7+Q8+Q9+Q10)
print("總分是",Total)

# 5. 測驗結果
if Total <= 2:
    print("0~2 個勾勾：繼續維持下去吧!恭喜你，你的心累指數只有10%！只要有想做的事情，你就會馬上去做，有想去的地方你也會馬上出發，每天都過得不無聊、滿充實的喔！內心變得充實的話，行動力也會隨之提高，相信你之後也會一步步的實現自己想做的事呢！繼續保持現在的良好狀態，試著接受不同的挑戰，吸收各式各樣的新事物吧！不過在努力的同時，也要記得好好休息喔！")

elif Total <= 5 and Total >= 3:
    print("3~5 個勾勾：要注意安撫情緒喔！你的心累指數是 40%，仍然是非常有活力的人。不過要小心一旦發生什麼事情，情緒可能容易變得消沉。你不是消極的人，反而是個努力家，但有時候過於努力，反而會造成疲倦與壓力。在到達極限之前，不如先抽個空讓自己好好休息。不然太過沉重的壓力有可能會壓垮你喔。")

elif Total <= 8 and Total >= 6:
    print("6~8 個勾勾：你已經有點危險了！你的心累指數是 60%，已經有點累了呢！但再這樣下去，壓力是不會消失的！你也是依然有想挑戰的新事物，但只有空想卻無法下定決心，只會讓時間一分一秒逝去。你可能心有餘而力不足，覺得有點不甘心；那就先試著從小小的挑戰開始做起吧！")

if Total >= 9:
    print("9~10 個勾勾：「快樂」是你的頭號課題！你的厭世指數有 80%，非常的高喔！你的內心狀態非常疲倦，每天的生活也讓你感到乏味至極。如果什麼事都覺得無聊又無趣的話，是因為你的內心狀態已經很疲倦，也很久沒有展開笑容了吧？對你來說，現在最重要的就是找回你自己的時間，試著一步步找到喜歡並且感興趣的事，努力讓自己重新充滿活力，再度快樂起來吧！")

# 6. 簡單道別
input("測驗做完啦!你覺得有準嗎?　")
print("嗯嗯，那改天再聊吧!希望下次見到你的時候，你更健康快樂了喔!　")
print("再見",name)
# Out:
# 嗨！你/妳好，請問大名？: chang
# chang 很高興認識你!
# 我叫Robot，是一個聊天機器人。
# 你最近會覺得因為心累，所以做事常提不起勁嗎?
# 是什麼原因呢?： 呼吸
# 沒關係。現在你可以一起來做做看下面的心理評估喔!
# 你的厭世指數，用10個問題馬上測! 以下問題若答案為No請回答0，Yes請回答1
# 最近嘆氣的次數愈來愈多　1
# 對人際交往感到厭煩，聽到手機響起就覺得煩躁無力　1
# 不太在乎自己的穿著，對時裝也失去興趣　1
# 認為運動好麻煩，會盡可能在家宅　1
# 吃什麼都淡而無味，對美食失去興趣　0
# 最近的活動範圍只有家裡、公司或學校　1
# 明明有件事需要處理，卻遲遲未開始　1
# 失去上進心，覺得「現在這樣也不錯」　1
# 認為談戀愛是麻煩事　1
# 放假時大多數時間都在睡覺　1
# 總分是 9
# 9~10 個勾勾：「快樂」是你的頭號課題！你的厭世指數有 80%，非常的高喔！你的內心狀態非常疲倦，每天的生活也讓你感到乏味至極。如果什麼事都覺得無聊又無趣的話，是因為你的內心狀態已經很疲倦，也很久沒有展開笑容了吧？對你來說，現在最重要的就是找回你自己的時間，試著一步步找到喜歡並且感興趣的事，努力讓自己重新充滿活力，再度快樂起來吧！
# 測驗做完啦!你覺得有準嗎?　準啦，哪次不準
# 嗯嗯，那改天再聊吧!希望下次見到你的時候，你更健康快樂了喔!
# 再見 chang
